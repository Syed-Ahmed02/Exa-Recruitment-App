# %% [markdown]
# ### Introduction
# In this tutorial, we use Exa to **automate** the entire process of **discovering**, **researching**, and **evaluating** exceptional candidates.
#
# Here's what we're going to do:
# 1. Candidate research: Identify potential candidates and use Exa to find additional details, such as personal websites, LinkedIn profiles, and their research topics.
#
# 2. Candidate evaluation: Evaluate candidates using an LLM to score their fit to our hiring criteria.
#
# 3. Finding more candidates: Discover more candidates similar to our top picks.
#
# This project requires an [Exa API key](https://dashboard.exa.ai/overview) and an [OpenAI API key](https://platform.openai.com/api-keys). Get 1000 Exa searches per month free just for [signing up](https://dashboard.exa.ai/overview)!

# %%
# install dependencies
# !pip install exa_py openai matplotlib tqdm

import pandas as pd
from exa_py import Exa
import openai

EXA_API_KEY = ''
OPENAI_API_KEY = ''

exa = Exa(api_key = EXA_API_KEY)
openai.api_key = OPENAI_API_KEY
# Out:
# Collecting exa_py
#   Downloading exa_py-1.0.9-py3-none-any.whl (6.3 kB)
# Collecting openai
#   Downloading openai-1.14.2-py3-none-any.whl (262 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.4/262.4 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from exa_py) (2.31.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from exa_py) (4.10.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.6.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.6)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.4-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 6.3 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.16.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->exa_py) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->exa_py) (2.0.7)
# Installing collected packages: h11, httpcore, exa_py, httpx, openai
# Successfully installed exa_py-1.0.9 h11-0.14.0 httpcore-1.0.4 httpx-0.27.0 openai-1.14.2

# %% [markdown]
# ### Initial Candidates
#
# Suppose I'm building Simile, an AI startup for web retrieval.
#
# My hiring criteria is:
# - AI experience
# - interest in retrieval, databases, and knowledge
# - available to work now or soon
#
# We start with 13 example PhD students recommended by friends. All I have is their name and email.

# %%
# Usually you would upload a csv of students
# df = pd.read_csv('./students.csv')

# TODO: add your own candidates
sample_data = {
    "Name": [
        "Kristy Choi", "Jiaming Song", "Brice Huang", "Andi Peng",
        "Athiya Deviyani", "Hao Zhu", "Zana Bucinca", "Usha Bhalla",
        "Kia Rahmani", "Jingyan Wang", "Jun-Kun Wang", "Sanmi Koyejo",
        "Erik Jenner"
    ],
    "Email": [
        "kristy@cs.stanford.edu", "song@cs.stanford.edu",
        "bricehuang@mit.edu", "andi@mit.edu",
        "deviyaniathiya@cs.cmu.edu", "haozhu@cmu.edu",
        "zana@seas.harvard.edu", "usha@g.harvard.edu",
        "kiarah@utexas.edu", "jingyanw@gatech.edu",
        "junkun@ucsd.edu", "sanmikoy@cs.stanford.edu",
        "erik@berkeley.edu"
    ]
}

# Creating the DataFrame
students_df = pd.DataFrame(sample_data)
students_df
# Out:
#                          Name                              Email
# 0                   FNU Aditi           aditi712@cs.stanford.edu
# 1                 Ahmed Ahmed            ahmedah@cs.stanford.edu
# 2                Ali Alkhatib                al2@cs.stanford.edu
# 3               Aryaman Arora            aryaman@cs.stanford.edu
# 4                Simran Arora             simran@cs.stanford.edu
# 5              Dilip Arumugam              dilip@cs.stanford.edu
# 6                 Anand Avati              avati@cs.stanford.edu
# 7                   Neil Band              nband@cs.stanford.edu
# 8                Andy Bartolo            bartolo@cs.stanford.edu
# 9             Suneel Belkhale           belkhale@cs.stanford.edu
# 10             Sergio Benitez           sbenitez@cs.stanford.edu
# 11      Michael Dawit Bereket           mbereket@cs.stanford.edu
# 12                Mark Berger           mjberger@cs.stanford.edu
# 13           Keller Blackwell            kellerb@cs.stanford.edu
# 14                  Guy Blanc             gblanc@cs.stanford.edu
# 15            Rishi Bommasani    rishi.bommasani@cs.stanford.edu
# 16            Josh Brakensiek  joshua.brakensiek@cs.stanford.edu
# 17           Beleicia Bullock           beleicia@cs.stanford.edu
# 18               Kaylee Burns           kayburns@cs.stanford.edu
# 19               Hancheng Cao           hanchcao@cs.stanford.edu
# 20                  Kaidi Cao           kaidicao@cs.stanford.edu
# 21                 Steven Cao              shcao@cs.stanford.edu
# 22                  Eric Chan       ericryanchan@cs.stanford.edu
# 23  Keshigeyan Chandrasegaran             keshik@cs.stanford.edu
# 24               Serina Chang            serinac@cs.stanford.edu
# 25        Alicja Chaszczewicz             alicja@cs.stanford.edu
# 26                 Annie Chen               asc8@cs.stanford.edu
# 27                 Mayee Chen             mfchen@cs.stanford.edu
# 28              Hansheng Chen            hshchen@cs.stanford.edu
# 29               Honglin Chen           honglinc@cs.stanford.edu
# 30                    Ed Chen            edjchen@cs.stanford.edu
# 31                 Sirui Chen            ericcsr@cs.stanford.edu
# 32                 Ziwei Chen         ziwei.chen@cs.stanford.edu
# 33                 Myra Cheng               myra@cs.stanford.edu
# 34                 Alan Cheng                ayc@cs.stanford.edu
# 35               Nicole Chiou           nicchiou@cs.stanford.edu
# 36                Kristy Choi             kechoi@cs.stanford.edu
# 37              Samuel Clarke           spclarke@cs.stanford.edu
# 38          Rachel Cleaveland           rcleavel@cs.stanford.edu
# 39              Kelly Cochran           kcochran@cs.stanford.edu
# 40            Spencer Compton           comptons@cs.stanford.edu

# %% [markdown]
# ### Information Enrichment
#
# Now, let's add more information about the candidates: current school, LinkedIn, and personal website.
#
# First, we'll define a helper function to call openAI -- we'll use this for many of our later functions.

# %%
def get_openai_response(input_text):
    # if contents is empty
    if not input_text:
        return ""
    completion = openai.chat.completions.create(
            model="gpt-3.5-turbo-0125",
            messages=[
                {"role": "system", "content": "You are a helpful assistant."},
                {"role": "user", "content": input_text},
            ],
            temperature=0
        )
    return completion.choices[0].message.content

# %% [markdown]
# We'll ask GPT to extract the candidate's school from their email address.

# %%
def extract_school_from_email(email):
  content =  f"I'm going to give you a student's email. I want you to figure out what school they go to. For example, if the email is john@cmu.edu you should return 'CMU' and nothing else. Only return the name of the school. Here is their email: {email}"
  return get_openai_response(content)

# Example
extract_school_from_email('sarah@csail.mit.edu')
# Out:
# 'MIT'

# %% [markdown]
# Now that we have their school, let's use Exa to find their LinkedIn and personal website too.
#
# Here, we're passing in ```type="keyword"``` to do an Exa keyword search because we want our results to have the exact name in the result. We also specify ```include_domains=['linkedin.com']``` to restrict the results to LinkedIn profiles.

# %%
def get_linkedin_from_name(name, school = ''):
    query = f"{name} {school}"

    keyword_search = exa.search(query, num_results=1, type="keyword", include_domains=['linkedin.com'])

    if keyword_search.results:
        result = keyword_search.results[0]
        return result.url
    print(f"No LinkedIn found for: {name}")
    return None

print("LinkedIn:", get_linkedin_from_name('Sarah Chieng', 'MIT'))
# Out:
# LinkedIn: https://www.linkedin.com/in/sarah-chieng-888595139

# %% [markdown]
# To now find the candidate's personal website, we can use the same Exa query, but we want to also scrape the website's contents. To do this, we use ```search_and_contents```.
#
# We can also exclude some misleading websites with ```exclude_domains=['linkedin.com', 'github.com', 'twitter.com']```. Whatever's left has a good chance of being their personal site!

# %%
#given a name, returns their personal website if we can find it
def exa_search_personal_website(name, school = ''):
    query = f"{name} {school}"
    keyword_search = exa.search_and_contents(query, type="keyword", text={"include_html_tags": False}, num_results=1, exclude_domains=['linkedin.com', 'github.com', 'twitter.com'])
    if keyword_search.results:
        result = keyword_search.results[0]
        return result.url, result.text
    print(f"No personal website found for: {name}")
    return (None, None)

#example
personal_website_url, personal_website_text = exa_search_personal_website('Aryaman Arora', 'Stanford')
personal_website_url
# Out:
# 'https://aryaman.io/'

# %% [markdown]
# Now that I have personal websites of each candidate, we can use Exa+GPT4 to answer questions like:
#
# - what are they doing now? Or what class year are they?
# - where did they do their undergrad?
# - what topics do they research?
# - are they an AI researcher?
#
# Once we have all of the page's contents, let's start asking some questions:

# %%
def extract_undergrad_from_contents(contents):
    contents = f"""I'm going to give you some information I found online about a person. Based on the provided information, determine where they went to college for undergrad.
    Some examples are \"MIT\" or \"Harvard.\" You should answer only in the example format, or return \"not sure\" if you're not sure. Do not return any other text. Here is the information I have scraped: {contents}."""
    return get_openai_response(contents)

def extract_current_role_from_contents(contents):
    contents = f"""I'm going to give you some information I found online about a person. Based on the provided information, determine where they are currently working or if they are still a student, what their current year of study is.
    Some examples are \"OpenAI\" or \"first year PHD.\" You should answer only in the example format, or return \"not sure\" if you're not sure. Do not return any other text. Here is the information I have scraped: {contents}."""
    return get_openai_response(contents)

def extract_research_topics_from_contents(contents):
    contents = f"""I'm going to give you some information I found online about a person. Based on the provided information, determine what fields they research.
    Some examples are \"RAG, retrieval, and databases\" or \"Diffusion models.\" You should answer only in the example format, or return \"not sure\" if you're not sure. Do not return any other text. Here is the information I have scraped: {contents}."""
    return get_openai_response(contents)

def extract_is_ai_from_contents(contents):
    contents = f"""I'm going to give you some information I found online about a person. Based on the provided information, determine whether they are a AI researcher.
    You should only return \"yes\" or \"no\", or return \"not sure\" if you're not sure. Do not return any other text. Here is the information I have scraped: {contents}."""
    return get_openai_response(contents)

#Example
personal_website_url, personal_website_text = exa_search_personal_website('Aryaman Arora', 'Stanford') # Note: this is a random person I found online using an Exa search

undergrad = extract_undergrad_from_contents(personal_website_text)
current = extract_current_role_from_contents(personal_website_text)
topics = extract_research_topics_from_contents(personal_website_text)
ai = extract_is_ai_from_contents(personal_website_text)

# Printing the information using f-string formatting
print(f"Personal Site: {personal_website_url}")
print(f"Undergrad: {undergrad}")
print(f"Current: {current}")
print(f"Topics: {topics}")
print(f"AI: {ai}")
# Out:
# Personal Site: https://aryaman.io/
# Undergrad: not sure
# Current: Ph.D. Student, Computer Science @ Stanford.
# Topics: interpretability
# AI: yes

# %% [markdown]
# ### Candidate Evaluation
# Next, we use GPT-4 to score candidates 1-10 based on fit. This way, we can use Exa to find more folks similar to our top-rated candidates.

# %%
# TODO: change these to fit your own criteria

def calculate_score(info, undergrad, year, researchTopics, AI):
    contents = f"""I'm going to provide some information about an individual, and I want you to rate on a scale of 1 to 10 how good of a hiring candidate they are. I am hiring for AI researchers.
    A 10 is someone who went to an incredible college, is graduating soon (final year PhD ideally) or is already graduated, is definitely an AI researcher, has a lot of experience and seems really smart, and a nice bonus is if their research is related to retrieval, search, databases. Only return an integer from 0 to 10. Do not return anything else. This candidate did undergrad at {undergrad} and their current role is {year}. Are they an AI researcher? {AI}. They do research in {researchTopics}. Here are some other things I know about them: {info}"""
    try:
        return int(get_openai_response(contents))
    except:
        return None

# %% [markdown]
# Finally, let's enrich our dataframe of people. We define a function `enrich_row` that uses all the functions we defined to learn more about a candidate,and sort by score to get the most promising candidates.

# %%
 # Set up progress bar
from tqdm.auto import tqdm
tqdm.pandas()

def enrich_row(row):
    row['School'] = extract_school_from_email(row['Email'])
    linkedIn_info = get_linkedin_from_name(row['Name'], row['School'])
    if linkedIn_info:
        row['LinkedIn'] = linkedIn_info
    website_url, website_info = exa_search_personal_website(row['Name'], row['School'])
    row['ExaWebsite'] = website_url
    row['ContentInfo'] = website_info
    row['Undergrad'] = extract_undergrad_from_contents(row['ContentInfo'])
    row['Role'] = extract_current_role_from_contents(row['ContentInfo'])
    row['ResearchTopics'] = extract_research_topics_from_contents(row['ContentInfo'])
    row['AI'] = extract_is_ai_from_contents(row['ContentInfo'])
    row['Score'] = calculate_score(row['ContentInfo'], row['Undergrad'], row['Role'], row['ResearchTopics'], row['AI'])
    return row

enriched_df = students_df.progress_apply(enrich_row, axis=1)
sorted_df = enriched_df.sort_values(by='Score', ascending=False).reset_index(drop=True)
sorted_df
# Out:
#   0%|          | 0/41 [00:00<?, ?it/s]
# No LinkedIn found for: Josh Brakensiek
# No LinkedIn found for: Kelly Cochran
#      AI                                        ContentInfo  \
# 0   yes  https://ai.stanford.edu/~kaidicao/\nKaidi Cao\...
# 1   yes  http://kristychoi.com/\nKristy Choi\n?\n   \n\...
# 2   yes  https://anniesch.github.io/\nAnnie S. Chen\n?\...
# 3   yes  https://mayeechen.github.io/\nHello, I’m Mayee...
# 4   yes  http://hanchengcao.me/\nHancheng Cao @ Stanfor...
# 5   yes  https://edjchen.me/\nEdward Chen's Homepage\n?...
# 6   yes  https://web.stanford.edu/~jbrakens/\nJoshua Br...
# 7   yes  https://rishibommasani.github.io/\nRishi Bomma...
# 8   yes  https://web.stanford.edu/~gblanc/\nGuy Blanc\n...
# 9   yes  https://keshik6.github.io/\nKeshigeyan Chandra...
# 10  yes  https://suneel.belkhale.com/\nSuneel Belkhale\...
# 11  yes  https://samuelpclarke.com/\nSamuel Clarke\n?\n...
# 12  yes  https://nband.github.io/\nNeil Band\n?\nNeil B...
# 13  yes  https://avati.github.io/\nAnand Avati\n?\n    ...
# 14  yes  https://dilipa.github.io/\nDilip Arumugam\n?\n...
# 15  yes  https://arorasimran.com/\nSimran Arora\n?\n   ...
# 16  yes  https://aryaman.io/\nAryaman Arora\n?\nMe\n   ...
# 17  yes  https://stairlab.stanford.edu/members/nicole_c...
# 18  yes  https://serinachang5.github.io/\nSerina Chang\...
# 19  yes  https://profiles.stanford.edu/sirui-chen\nSiru...
# 20  yes  https://web.stanford.edu/~honglinc/\nHonglin C...
# 21  yes  https://lakonik.github.io/\nHome | Hansheng Ch...
# 22  yes  https://profiles.stanford.edu/rachel-cleavelan...
# 23  yes  https://profiles.stanford.edu/247412\nZiwei Ch...
# 24  yes  https://profiles.stanford.edu/spencer-compton\...
# 25  yes  https://stevenxcao.github.io/\nSteven Cao\n?\n...
# 26  yes  https://knight-hennessy.stanford.edu/people/ah...
# 27  yes  https://kayburns.github.io/\nkaylee\n?\n   \n ...
# 28  yes  https://ccsre.stanford.edu/people/beleicia-bul...
# 29  yes  https://ericryanchan.github.io/about.html\nEri...
# 30  yes  https://knight-hennessy.stanford.edu/people/ke...
# 31  yes  https://myracheng.github.io/\nMyra Cheng\n?\nM...
# 32  yes  https://stanford.edu/~bartolo/\nAndy Bartolo\n...
# 33  yes  https://profiles.stanford.edu/kelly-cochran\nK...
# 34  yes  https://ali-alkhatib.com/\nAli Alkhatib\n?\n  ...
# 35  yes  https://sergio.bz/\nSergio Benitez - Who Am I?...
# 36   no  https://markjberger.com/menu/about/\nAbout\n?\...
# 37   no  https://med.stanford.edu/profiles/alan-cheng\n...
# 38   no  https://profiles.stanford.edu/michael-bereket\...
# 39   no  https://www4.cs.stanford.edu/directory/phd-stu...
# 40   no  https://legacy.cs.stanford.edu/directory/phd-s...
#
#                                 Email  \
# 0            kaidicao@cs.stanford.edu
# 1              kechoi@cs.stanford.edu
# 2                asc8@cs.stanford.edu
# 3              mfchen@cs.stanford.edu
# 4            hanchcao@cs.stanford.edu
# 5             edjchen@cs.stanford.edu
# 6   joshua.brakensiek@cs.stanford.edu
# 7     rishi.bommasani@cs.stanford.edu
# 8              gblanc@cs.stanford.edu
# 9              keshik@cs.stanford.edu
# 10           belkhale@cs.stanford.edu
# 11           spclarke@cs.stanford.edu
# 12              nband@cs.stanford.edu
# 13              avati@cs.stanford.edu
# 14              dilip@cs.stanford.edu
# 15             simran@cs.stanford.edu
# 16            aryaman@cs.stanford.edu
# 17           nicchiou@cs.stanford.edu
# 18            serinac@cs.stanford.edu
# 19            ericcsr@cs.stanford.edu
# 20           honglinc@cs.stanford.edu
# 21            hshchen@cs.stanford.edu
# 22           rcleavel@cs.stanford.edu
# 23         ziwei.chen@cs.stanford.edu
# 24           comptons@cs.stanford.edu
# 25              shcao@cs.stanford.edu
# 26            ahmedah@cs.stanford.edu
# 27           kayburns@cs.stanford.edu
# 28           beleicia@cs.stanford.edu
# 29       ericryanchan@cs.stanford.edu
# 30            kellerb@cs.stanford.edu
# 31               myra@cs.stanford.edu
# 32            bartolo@cs.stanford.edu
# 33           kcochran@cs.stanford.edu
# 34                al2@cs.stanford.edu
# 35           sbenitez@cs.stanford.edu
# 36           mjberger@cs.stanford.edu
# 37                ayc@cs.stanford.edu
# 38           mbereket@cs.stanford.edu
# 39           aditi712@cs.stanford.edu
# 40             alicja@cs.stanford.edu
#
#                                            ExaWebsite  \
# 0                  https://ai.stanford.edu/~kaidicao/
# 1                              http://kristychoi.com/
# 2                         https://anniesch.github.io/
# 3                        https://mayeechen.github.io/
# 4                              http://hanchengcao.me/
# 5                                 https://edjchen.me/
# 6                 https://web.stanford.edu/~jbrakens/
# 7                   https://rishibommasani.github.io/
# 8                   https://web.stanford.edu/~gblanc/
# 9                          https://keshik6.github.io/
# 10                       https://suneel.belkhale.com/
# 11                         https://samuelpclarke.com/
# 12                           https://nband.github.io/
# 13                           https://avati.github.io/
# 14                          https://dilipa.github.io/
# 15                           https://arorasimran.com/
# 16                                https://aryaman.io/
# 17  https://stairlab.stanford.edu/members/nicole_c...
# 18                    https://serinachang5.github.io/
# 19           https://profiles.stanford.edu/sirui-chen
# 20                https://web.stanford.edu/~honglinc/
# 21                         https://lakonik.github.io/
# 22    https://profiles.stanford.edu/rachel-cleaveland
# 23               https://profiles.stanford.edu/247412
# 24      https://profiles.stanford.edu/spencer-compton
# 25                      https://stevenxcao.github.io/
# 26  https://knight-hennessy.stanford.edu/people/ah...
# 27                        https://kayburns.github.io/
# 28  https://ccsre.stanford.edu/people/beleicia-bul...
# 29          https://ericryanchan.github.io/about.html
# 30  https://knight-hennessy.stanford.edu/people/ke...
# 31                       https://myracheng.github.io/
# 32                     https://stanford.edu/~bartolo/
# 33        https://profiles.stanford.edu/kelly-cochran
# 34                          https://ali-alkhatib.com/
# 35                                 https://sergio.bz/
# 36                https://markjberger.com/menu/about/
# 37       https://med.stanford.edu/profiles/alan-cheng
# 38      https://profiles.stanford.edu/michael-bereket
# 39  https://www4.cs.stanford.edu/directory/phd-stu...
# 40  https://legacy.cs.stanford.edu/directory/phd-s...
#
#                                              LinkedIn  \
# 0     https://www.linkedin.com/in/kaidi-cao-398131117
# 1              https://www.linkedin.com/in/kristyc424
# 2            https://www.linkedin.com/in/annie-s-chen
# 3    https://www.linkedin.com/in/mayee-chen-5a7290104
# 4   https://www.linkedin.com/in/hancheng-cao-2480a0b9
# 5    https://www.linkedin.com/in/edward-chen-958a7bb4
# 6                                                 NaN
# 7                 https://www.linkedin.com/in/rishi-b
# 8              https://www.linkedin.com/in/guy-wilson
# 9   https://www.linkedin.com/in/keshigeyan-chandra...
# 10     https://www.linkedin.com/in/suneel-b-032b1a101
# 11          https://www.linkedin.com/in/samuelpclarke
# 12  https://www.linkedin.com/posts/stanford-univer...
# 13             https://www.linkedin.com/in/anandavati
# 14          https://www.linkedin.com/in/diliparumugam
# 15           https://www.linkedin.com/in/simran-arora
# 16      https://www.linkedin.com/in/aryaman-arora2020
# 17           https://www.linkedin.com/in/nicole-chiou
# 18           https://www.linkedin.com/in/serina-chang
# 19  https://www.linkedin.com/in/%E6%80%9D%E7%9D%BF...
# 20  https://www.linkedin.com/in/honglin-chen-52b13...
# 21  https://www.linkedin.com/in/hansheng-chen-339b...
# 22  https://www.linkedin.com/in/rachel-cleaveland-...
# 23             https://www.linkedin.com/in/ziwei-chen
# 24        https://www.linkedin.com/in/spencer-compton
# 25   https://www.linkedin.com/in/steven-cao-680833149
# 26  https://www.linkedin.com/in/ahmed-ahmed-13914510a
# 27            https://www.linkedin.com/in/kayleeburns
# 28        https://www.linkedin.com/in/beleiciabullock
# 29    https://www.linkedin.com/in/eric-chan-28353322a
# 30    https://www.linkedin.com/in/erica-liu-6a6249291
# 31           https://www.linkedin.com/in/myracheng027
# 32          https://www.linkedin.com/in/andrewbartolo
# 33                                                NaN
# 34             https://www.linkedin.com/in/asalkhatib
# 35  https://www.linkedin.com/in/sergio-benitez-925...
# 36            https://www.linkedin.com/in/markjberger
# 37    https://www.linkedin.com/in/alan-cheng-3a628b52
# 38        https://www.linkedin.com/in/michael-bereket
# 39  https://www.linkedin.com/in/aditi-partap-28611ab2
# 40  https://www.linkedin.com/posts/alicjachaszczew...
#
#                          Name  \
# 0                   Kaidi Cao
# 1                 Kristy Choi
# 2                  Annie Chen
# 3                  Mayee Chen
# 4                Hancheng Cao
# 5                     Ed Chen
# 6             Josh Brakensiek
# 7             Rishi Bommasani
# 8                   Guy Blanc
# 9   Keshigeyan Chandrasegaran
# 10            Suneel Belkhale
# 11              Samuel Clarke
# 12                  Neil Band
# 13                Anand Avati
# 14             Dilip Arumugam
# 15               Simran Arora
# 16              Aryaman Arora
# 17               Nicole Chiou
# 18               Serina Chang
# 19                 Sirui Chen
# 20               Honglin Chen
# 21              Hansheng Chen
# 22          Rachel Cleaveland
# 23                 Ziwei Chen
# 24            Spencer Compton
# 25                 Steven Cao
# 26                Ahmed Ahmed
# 27               Kaylee Burns
# 28           Beleicia Bullock
# 29                  Eric Chan
# 30           Keller Blackwell
# 31                 Myra Cheng
# 32               Andy Bartolo
# 33              Kelly Cochran
# 34               Ali Alkhatib
# 35             Sergio Benitez
# 36                Mark Berger
# 37                 Alan Cheng
# 38      Michael Dawit Bereket
# 39                  FNU Aditi
# 40        Alicja Chaszczewicz
#
#                                        ResearchTopics  \
# 0   Machine learning, efficient learning algorithm...
# 1   Machine learning with limited labeled supervis...
# 2                 Adaptation to changing environments
# 3   Data-centric AI, data selection, data labeling...
# 4   social computing, computational social science...
# 5   Machine learning, model evaluation, fairness, ...
# 6                                            not sure
# 7   Societal impact of AI, especially foundation m...
# 8                              Decision tree learning
# 9   Generative Modeling, Model Inversion Attacks, ...
# 10                                   Diffusion models
# 11  Robot Learning for Manipulation of Granular Ma...
# 12                             Bayesian deep learning
# 13           Machine learning, probabilistic modeling
# 14                             Reinforcement learning
# 15                           Machine learning systems
# 16                                   interpretability
# 17  causal inference, machine learning, healthcare...
# 18  Graph Neural Networks, Temporal Graphs, Supply...
# 19                                           not sure
# 20  Self-supervised learning from large-scale vide...
# 21                                3D Diffusion models
# 22  Her research focuses on symbolic execution and...
# 23                                           not sure
# 24                                           not sure
# 25  natural language processing, machine learning,...
# 26                                   Computer science
# 27                                           not sure
# 28                                           not sure
# 29                                           not sure
# 30      Computer security, cryptography, mathematics.
# 31                                           not sure
# 32                                           not sure
# 33                Regulatory DNA and gene expression.
# 34                         Human-computer interaction
# 35  Operating systems, cryptosystems, programming ...
# 36                             computational genomics
# 37                                           not sure
# 38                                           not sure
# 39                                           not sure
# 40                                           not sure
#
#                                                  Role    School  Score  \
# 0   Final-year Computer Science Ph.D. candidate at...  Stanford      9
# 1   final-quarter Ph.D. candidate in Computer Scie...  Stanford      9
# 2   third-year computer science PhD student at Sta...  Stanford      9
# 3   Stanford University, PhD student, Computer Sci...  Stanford      9
# 4   Stanford - Final year PhD candidate in Departm...  Stanford      9
# 5         2nd-year PhD student at Stanford University  Stanford      9
# 6   PhD student in Computer Science at Stanford Un...  Stanford      9
# 7   Stanford Center for Research on Foundation Mod...  Stanford      9
# 8          STANFORD UNIVERSITY, PHD STUDENT, 5TH YEAR  Stanford      9
# 9                          PhD at Stanford University  Stanford      9
# 10  Doctoral Candidate Computer Science, Stanford ...  Stanford      9
# 11                PhD Student at Stanford University.  Stanford      9
# 12                                          Google AI  Stanford      9
# 13                  final year PhD at Stanford AI Lab  Stanford      9
# 14                                           not sure  Stanford      9
# 15                                     first year PHD  Stanford      9
# 16        Ph.D. Student, Computer Science @ Stanford.  Stanford      9
# 17              second-year Ph.D. student at Stanford  Stanford      8
# 18                                           not sure  Stanford      8
# 19                                           not sure  Stanford      8
# 20                                           not sure  Stanford      8
# 21                                           not sure  Stanford      8
# 22                                       3rd year PHD  Stanford      8
# 23                                   first year Ph.D.  Stanford      8
# 24                                   first year Ph.D.  Stanford      8
# 25                        second-year PhD at Stanford  Stanford      8
# 26                                     third year PHD  Stanford      8
# 27                                           not sure  Stanford      8
# 28  second year doctoral student in the Department...  Stanford      8
# 29                           2nd year PhD at Stanford  Stanford      7
# 30                                     third year PHD  Stanford      7
# 31                                     third year PHD  Stanford      7
# 32                                   sixth-year Ph.D.  Stanford      7
# 33                                           not sure  Stanford      7
# 34                                           not sure  Stanford      5
# 35                                           not sure  Stanford      4
# 36                                          Robinhood  Stanford      2
# 37                                           not sure  Stanford      2
# 38                                           not sure  Stanford      2
# 39                                           not sure  Stanford      2
# 40                                           not sure  Stanford      0
#
#                           Undergrad
# 0               Tsinghua University
# 1                          Columbia
# 2                          Stanford
# 3              Princeton University
# 4               Tsinghua University
# 5     Pennsylvania State University
# 6        Carnegie Mellon University
# 7                           Cornell
# 8                          not sure
# 9               Stanford University
# 10              Stanford University
# 11  Georgia Institute of Technology
# 12                         not sure
# 13                         Stanford
# 14                         not sure
# 15       University of Pennsylvania
# 16                         not sure
# 17       University of Pennsylvania
# 18                         not sure
# 19                         Stanford
# 20                         not sure
# 21                         not sure
# 22                         Stanford
# 23                         not sure
# 24                         not sure
# 25                      UC Berkeley
# 26                         Stanford
# 27                         not sure
# 28                  Bowdoin College
# 29                         not sure
# 30      University of South Florida
# 31                          Caltech
# 32                         Stanford
# 33                         Stanford
# 34                        UC Irvine
# 35                              MIT
# 36              Stanford University
# 37                         Stanford
# 38                         not sure
# 39                         not sure
# 40                         not sure

# %% [markdown]
# ### Finding more candidates
# Now that we know how to research candidates, let's find some more! We'll take each of the top candidates (score 7-10), and use Exa to find similar profiles.
#
# Exa's ```find_similar```,allows us to search a URL and find semantically similar URLs. For example, I could search 'hinge.co' and it'll return the homepages of similar dating apps. In this case, we'll pass in the homepages of our top candidates to find similar profiles.

# %%
# given a homepage, get homepages of similar candidates

def get_more_candidates(homepageURL):
  new_homepages = []
  if not homepageURL:
    return None
  similarity_search = exa.find_similar_and_contents(homepageURL, num_results=3, text={"include_html_tags": False}, exclude_domains=['linkedin.com', 'github.com', 'twitter.com'])

  #return a list of emails
  for res in similarity_search.results:
    new_homepages.append((res.url, res.text))
  return new_homepages

# we can already get things like role and education, but we need to get the name and email this time
def get_name_from_contents(contents):
    content = f"""I'm going to give you some information I found online about a person. Based on the provided information, figure out their full name.
    Some examples are \"Sarah Chieng\" or \"Will Bryk.\" You should answer only in the example format, or return \"not sure\" if you're not sure. Do not return any other text. Here is the information I have scraped: {contents}."""
    return get_openai_response(content)

def get_email_from_contents(contents):
    content = f"""I'm going to give you some information I found online about a person. Based on the provided information, figure out their email.
    Some examples are \"sarah@exa.ai\" or \"will@harvard.edu.\" You should answer only in the example format, or return \"not sure\" if you're not sure. Do not return any other text. Here is the information I have scraped: {contents}."""
    return get_openai_response(content)

# Example
example_homepage = ('https://winniexu.ca/')
additional_homepages = get_more_candidates(example_homepage)
new_candidate_url, new_candidate_content = additional_homepages[0]
name = get_name_from_contents(new_candidate_content)
email = get_email_from_contents(new_candidate_content)


print(f"Additional Homepages:{additional_homepages}")
print(f"Name:{name}")
print(f"Email: {email}")
# Out:
# Additional Homepages:[('https://evgenii-nikishin.github.io/', "  \n\n\n \n\n\n\n\nI am a PhD student at Mila, University of Montreal, where I have the good fortune of being advised by Pierre-Luc Bacon and Aaron Courville. I am broadly interested in Reinforcement Learning and using capabilities of Deep Learning for decision making.\n \n\n Previously, I spent 1.5 years at Cornell University. I received an MS in Computer Science from Higher School of Economics and Skoltech where I worked with Dmitry Vetrov at the Samsung Lab.\n I did my undergrad in CS at Lomonosov Moscow State University supervised by Alexander Dyakonov. \n \n\n During the 2nd half of 2022, I interned in the RL team at DeepMind London working closely with André Barreto, Junhyuk Oh, and Will Dabney.\n I spent summer 2020 remotely interning at Mila with Pierre-Luc Bacon and Yoshua Bengio.\n In summer 2018, I interned at ETH Zürich with Gunnar Rätsch applying RL for personal treatment. \n \n \n\nEmail \xa0/\xa0\n CV \xa0/\xa0\n Google Scholar \xa0/\xa0\n Twitter \xa0/\xa0\n GitHub\n\n\n\n\n\n\n\n \n \n\n\n\n\n\n\n\n Zhixuan Lin,\n Pierluca D'Oro,\n Evgenii Nikishin,\n Aaron Courville\n \nICLR 2024\n\n [PDF]\n \n \n We demonstrate that individual ensemble members in RL exhibit surprisingly low performance (whilst aggregate returns are adequate) and propose a remedy.\n \n\n\n\n\n\n\n\n\n\nEvgenii Nikishin,\n Junhyuk Oh,\n Georg Ostrovski,\n Clare Lyle,\n Razvan Pascanu,\n Will Dabney,\n André Barreto\n \nNeurIPS 2023 ; also ICLR 2023 Workshop Track \n\n [PDF,\n Poster]\n \n \n We propose an intervention for diagnosing the loss of plasticity phenomenon in RL and dynamically growing neural networks in RL for increasing computational efficiency.\n \n\n\n\n\n\n\n\n\n\n Clare Lyle,\n Zeyu Zheng,\n Evgenii Nikishin,\n Bernardo Ávila Pires,\n Razvan Pascanu,\n Will Dabney\n \nICML 2023 \n\n [PDF]\n \n \n An analysis of plasticity loss showing its relation to pathological loss landscapes and demonstrating efficiency of layer normalization to mitigate it.\n \n\n\n\n\n\n\n\n\n\n Pierluca D'Oro*,\n Max Schwarzer*,\n Evgenii Nikishin,\n Pierre-Luc Bacon,\n Marc G. Bellemare,\n Aaron Courville\n \nICLR 2023 ; also NeurIPS 2022 Workshop Track\n\n [PDF,\n Poster,\n Code]\n \n \n Resets unlock increasing sample efficiency by scaling the number of updates per environment step.\n \n\n\n\n\n\n\n\n\n\nEvgenii Nikishin*,\n Max Schwarzer*,\n Pierluca D'Oro*,\n Pierre-Luc Bacon,\n Aaron Courville\n \nICML 2022; also RLDM 2022\n\n [PDF,\n Short RLDM version,\n Code,\n Poster,\n Blog]\n \n \n We identify a damaging tendency of deep RL agents to overfit early experiences and propose a simple yet powerful remedy based on periodic resetting of a part of the agent.\n \n\n\n\n\n\n\n\n\n\nEvgenii Nikishin,\n Romina Abachi,\n Rishabh Agarwal,\n Pierre-Luc Bacon\n \nAAAI 2022; also ICML 2021 Workshop Track\n\n [PDF,\n Code,\n Poster]\n \n \n A model learning method for RL that directly optimizes the sum of rewards instead of likelihood, a proxy to the agent's objective.\n \n\n\n\n\n\n\n\n\n\n Volodymyr Kuleshov,\n Evgenii Nikishin,\n Shantanu Thakoor,\n Tingfung Lau,\n Stefano Ermon\n \nArXiv\n\n [PDF]\n \n \n We propose an algorithm to construct discrete token adversarial examples based on the notion of synonyms.\n \n\n\n\n\n\n\n\n\n\nEvgenii Nikishin,\n Arsenii Ashukha,\n Dmitry Vetrov\n \nNeurIPS 2019 Workshop Track\n\n [PDF,\n Code,\n Poster]\n \n \n Domain adaptation via learning shared dynamics in a latent space with adversarial matching of latent states.\n \n\n\n\n\n\n\n\n\n\nEvgenii Nikishin,\n Pavel Izmailov,\n Ben Athiwaratkun,\n Dmitrii Podoprikhin,\n Timur Garipov,\n Pavel Shvechikov,\n Dmitry Vetrov,\n Andrew Gordon Wilson\n \nUAI 2018 Workshop Track\n\n [PDF,\n Poster]\n \n \n Averaging weights during training of an RL agent stabilizes the achieved performance.\n \n\n\n \n\nLast update: Mar 2024.\n\n\n\n  "), ('https://jeakwon.github.io', '  Visualizing reactive astrocyte-neuron intera ...
# Name:Evgenii Nikishin
# Email: not sure

# %% [markdown]
# Final stretch -- let's put it all together. Let's find and add our new candidates to our original dataframe.

# %%
def new_candidates_df(df):
    # get the websites of our top candidates
    top_candidates_df = df[df['Score'] > 7]
    websites_list = top_candidates_df['ExaWebsite'].tolist()

    # use those top candidates to find new candidates
    new_candidates = set()
    for url in websites_list:
      new_candidates.update(get_more_candidates(url))

    #for each new candidate, get their information and add them to the dataframe
    names = []
    emails = []
    urls = []
    for url, content in tqdm(new_candidates):
      names.append(get_name_from_contents(content))
      emails.append(get_email_from_contents(content))
      urls.append(url)

    new_df = pd.DataFrame({
        'Name': names,
        'Email': emails,
        'ExaWebsite': urls,
    })

    return new_df

new_df = new_candidates_df(sorted_df)
new_df
# Out:
#   0%|          | 0/21 [00:00<?, ?it/s]
#                 Name                    Email  \
# 0           not sure                 not sure
# 1           not sure                 not sure
# 2           not sure                 not sure
# 3           not sure                 not sure
# 4           not sure                 not sure
# 5         Yuxin Chen  yuxin.chen@uchicago.edu
# 6         Min-Ho Nam                 not sure
# 7           not sure                 not sure
# 8           not sure                 not sure
# 9           not sure                 not sure
# 10       Felix Biggs                 not sure
# 11          not sure                 not sure
# 12     Aishik Mandal                 not sure
# 13  Evgenii Nikishin                 not sure
# 14       Mira Murati                 not sure
# 15          not sure                 not sure
# 16          not sure                 not sure
# 17          not sure                 not sure
# 18          not sure                 not sure
# 19        Chuanyi Ji                 not sure
# 20          Megan Ma       megan@stanford.edu
#
#                                            ExaWebsite
# 0   https://foster.uw.edu/academics/degree-program...
# 1                       http://3.131.28.213/index.php
# 2                             https://haoran-qiu.com/
# 3                             https://ponnekanti.net/
# 4                              https://ianosband.com/
# 5         https://cs.uchicago.edu/people/yuxin-chen1/
# 6                           https://jeakwon.github.io
# 7         https://abney.github.io/vinartus/index.html
# 8        https://public.websites.umich.edu/~charchan/
# 9                          http://mckinziebrandon.me/
# 10                             http://felixbiggs.com/
# 11  http://domain-registrar.storage.googleapis.com...
# 12                       https://jitaishik.github.io/
# 13                https://evgenii-nikishin.github.io/
# 14  https://digitaleconomy.stanford.edu/people/mir...
# 15  https://sites.google.com/view/emmavaninwegen/home
# 16                            https://ethanperez.net/
# 17                 https://glowhost.com/suspended.php
# 18                        https://ericbzhou.github.io
# 19        https://ece.gatech.edu/directory/chuanyi-ji
# 20                 https://law.stanford.edu/megan-ma/

# %% [markdown]
# Alrighty, that's it! We've just built an automated way of finding, researching, and evaluating candidates. You can use this for recruiting, or tailor this to find customers, companies, etc.
#
# And the best part is that every time you use Exa to find new candidates, you can do more  ```find_similar(new_candidate_homepage)``` searches with the new candidates as well -- helping you build an infinite list!
#
# Hope this tutorial was helpful and don't forget, you can get started with [Exa for free](https://dashboard.exa.ai/overview) :)
